# %% [markdown]
# #### 1번
#
# region_1, region_2라는 컬럼 이름은 지역 정보를 나타내기에는 너무 의미가 부족합니다.
#
# reviews 데이터프레임의 복사본을 만들고:
# * region_1 → region
# * region_2 → locale
# 로 이름 변경하기

# %%
# Your code here
renamed = reviews.rename(columns=dict(region_1='region', region_2='locale'))

# Check your answer
# q1.check()

# %% [markdown]
# #### 2번
#
# 데이터셋의 인덱스 이름(index name)을 "wines"로 설정하세요.

# %%
reindexed = reviews.rename_axis('wines', axis='rows')

# Check your answer
#q2.check()

# %% [markdown]
# #### 3번
#
# 두 subreddit 중 하나라도 언급된 제품들을 하나의 DataFrame으로 만드세요.

# %%
combined_products = pd.concat([gaming_products, movie_products])

# Check your answer
# q3.check()

# %% [markdown]
# #### 4번
#
# 두 테이블을 하나로 합친 데이터셋을 만드세요.
#
# * MeetID를 기준으로 두 DataFrame 합치기

# %%
powerlifting_combined = powerlifting_meets.set_index("MeetID").join(powerlifting_competitors.set_index("MeetID"))

# Check your answer
# q4.check()
