# %% [markdown]
# #### 1번
#
# reviews 데이터프레임에서 description 컬럼을 선택해서 desc 변수에 저장하세요.

# %%
# Your code here
desc = reviews['description']

# Check your answer
# q1.check()

# %% [markdown]
# #### 2번
#
# description 컬럼의 첫 번째 값을 선택해서 first_description 변수에 저장하세요.

# %%
first_description = reviews.description.iloc[0]

# Check your answer
# q2.check()
first_description

# %% [markdown]
# #### 3번
#
# reviews의 첫 번째 행(레코드)을 선택해서 first_row 변수에 저장하세요.

# %%
first_row = reviews.iloc[0]

# Check your answer
# q3.check()
first_row

# %% [markdown]
# #### 4번
#
# description 컬럼의 처음 10개 값을 선택해서 first_descriptions 변수에 저장하세요.
#
# 결과는 pandas Series 형태여야 합니다.

# %%
first_descriptions = desc.iloc[:10]

# Check your answer
# q4.check()
first_descriptions

# %% [markdown]
# #### 5번
#
# 인덱스가 1, 2, 3, 5, 8 인 행들을 선택해서 sample_reviews 변수에 저장하세요.

# %%
sample_reviews = reviews.iloc[[1, 2, 3, 5, 8]]

# Check your answer
# q5.check()
sample_reviews

# %% [markdown]
# #### 6번
#
# 인덱스가 0, 1, 10, 100 인 행들 중에서
#
# * country
# * province
# * region_1
# * region_2
#
# 컬럼만 선택하여 df 변수에 저장하세요.

# %%
df = reviews.iloc[[0, 1, 10, 100]][['country', 'province', 'region_1', 'region_2']]

# Check your answer
# q6.check()
df

# %% [markdown]
# #### 7번
#
# 처음 100개의 행에서
#
# * country
# * variety
#
# 컬럼만 선택하여 df 변수에 저장하세요.
#
# * iloc는 파이썬 기본 슬라이싱 규칙을 사용합니다.
# * 하지만 loc는 마지막 값도 포함합니다.

# %%
df = reviews.loc[0:99, ['country', 'variety']]

# Check your answer
# q7.check()
df

# %% [markdown]
# #### 8번
#
# 이탈리아에서 생산된 와인 리뷰만 포함하는 DataFrame italian_wines를 만드세요.
#
# 힌트
# ```python
# reviews.country == ?
# ```

# %%
italian_wines = reviews.loc[reviews.country == 'Italy']

# Check your answer
q8.check()

# %% [markdown]
# #### 9번
#
# 다음 조건을 만족하는 리뷰만 포함하는 top_oceania_wines DataFrame을 만드세요.
#
# 조건:
#
# * 점수(points)가 95 이상
# * 국가(country)가 Australia 또는 New Zealand
#
# 인 데이터만 선택하세요.

# %%
top_oceania_wines = reviews.loc[(reviews.country.isin(['Australia', 'New Zealand'])) & (reviews.points >= 95)]

# Check your answer
q9.check()
top_oceania_wines
