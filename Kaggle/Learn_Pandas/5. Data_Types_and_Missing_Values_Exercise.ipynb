# %% [markdown]
# #### 1번
#
# 데이터셋의 points 컬럼의 데이터 타입(dtype)은 무엇인가요?

# %%
# Your code here
dtype = reviews.points.dtype

# Check your answer
# q1.check()

# %% [markdown]
# #### 2번
#
# points 컬럼의 값들로 새로운 Series를 만들되, 각 값을 문자열(string) 타입으로 변환하세요.

# %%
point_strings = reviews.points.astype(str)

# Check your answer
# q2.check()

# %% [markdown]
# #### 3번
#
# price 컬럼에는 비어 있는 값(null)이 있습니다.
# 가격이 없는 리뷰는 총 몇 개인가요?

# %%
n_missing_prices = reviews.price.isnull().sum()

# Check your answer
# q3.check()

# %% [markdown]
# #### 4번
#
# 가장 자주 등장하는 와인 생산 지역은 어디인가요?
#
# region_1 컬럼에서:
# 1. 각 값이 몇 번 등장하는지 세기
# 2. 결측값(NaN)은 "Unknown"으로 바꾸기
# 3. 등장 횟수 기준 내림차순 정렬하기
#
# ```python
# Unknown                    21247
# Napa Valley                 4480
#                            ...
# Bardolino Superiore            1
# Primitivo del Tarantino        1
# Name: region_1, Length: 1230, dtype: int64
# ```

# %%
reviews_per_region = reviews.region_1.fillna("Unknown").value_counts().sort_values(ascending=False)

# Check your answer
# q4.check()
