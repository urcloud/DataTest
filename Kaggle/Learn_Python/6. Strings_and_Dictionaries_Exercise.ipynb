# %% [markdown]
# #### 0a
#
# 빈 문자열 ""의 길이를 구하는 문제
# 문자열 안에 아무 문자도 없으므로 길이는 0

# %%
a = ""
length = 0
# q0.a.check()

# %% [markdown]
# #### 0b
#
# 문자열 "it's ok"의 길이 계산

# %%
b = "it's ok"
length = 7
# q0.b.check()

# %% [markdown]
# #### 0c
#
# \' 는 작은따옴표 ' 자체를 의미

# %%
c = 'it\'s ok'
length = 7
# q0.c.check()

# %% [markdown]
# #### 0d
#
# 문자열 "hey" 의 길이

# %%
d = """hey"""
length = 3
# q0.d.check()

# %% [markdown]
# #### 0e
#
# \n 은 줄바꿈 문자(newline)
# 화면에는 안 보이지만 문자 1개로 취급

# %%
e = '\n'
length = 1
# q0.e.check()

# %% [markdown]
# #### 1번
#
# 미국 우편번호(zip code)가 올바른 형식인지 검사하는 함수 작성 문제.
#
# 유효한 zip code란:
# * 정확히 5자리여야 하고
# * 모두 숫자여야 함
#
# 문자열 메서드(str method)를 사용하라고 함.
# → isdigit() 사용 가능

# %%
def is_valid_zip(zip_code):
    """Returns whether the input string is a valid (5 digit) zip code
    """
    
    return len(zip_code) == 5 and zip_code.isdigit()

# Check your answer
# q1.check()

# %% [markdown]
# #### 2번
#
# 뉴스 기사 목록(doc_list)에서 특정 키워드(keyword)가 들어있는 문서의 인덱스를 찾는 함수 작성.
# * 단어 일부만 포함된 경우는 제외
# * 대소문자 구분 X
# * 마침표(.) 와 쉼표(,) 무시

# %%
def word_search(doc_list, keyword):
    """
    Takes a list of documents (each document is a string) and a keyword. 
    Returns list of the index values into the original list for all documents 
    containing the keyword.

    Example:
    doc_list = ["The Learn Python Challenge Casino.", "They bought a car", "Casinoville"]
    >>> word_search(doc_list, 'casino')
    >>> [0]
    """
    result = []

    for i, doc in enumerate(doc_list):
        words = doc.lower().replace('.', '').replace(',', '').split()

        if keyword.lower() in words:
            result.append(i)

    return result

# Check your answer
# q2.check()

# %% [markdown]
# #### 3번
#
# 이번에는 키워드를 여러 개 검색.
#
# 각 키워드마다:
# * 어떤 문서에 포함되어 있는지
# * 문서 인덱스 리스트로 저장
#
# 결과를 dictionary 형태로 반환.

# %%
def multi_word_search(doc_list, keywords):
    """
    Takes list of documents (each document is a string) and a list of keywords.  
    Returns a dictionary where each key is a keyword, and the value is a list of indices
    (from doc_list) of the documents containing that keyword

    >>> doc_list = ["The Learn Python Challenge Casino.", "They bought a car and a casino", "Casinoville"]
    >>> keywords = ['casino', 'they']
    >>> multi_word_search(doc_list, keywords)
    {'casino': [0, 1], 'they': [1]}
    """
    
    result = {}

    for keyword in keywords:
        result[keyword] = word_search(doc_list, keyword)

    return result

# Check your answer
# q3.check()
