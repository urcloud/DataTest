# %% [markdown]
# #### 첫 번째 Python 코딩 문제에 오신 것을 환영합니다
#
# 처음으로 Kaggle Notebook을 사용한다면, 환영합니다!
#
# 노트북은 텍스트 블록(셀) 과 코드 블록(셀) 로 구성됩니다.
# 모든 셀은 수정 가능하지만, 주로 여러분은 코드 셀을 수정하여 문제를 풀게 됩니다.
#
#
# #### 코드 실행해보기
#
# 아래 코드 셀을 실행해보세요.
#
# 실행 방법:
# * ► 버튼 클릭
# * 또는 셀 클릭 후 Ctrl + Enter

# %%
print("You've successfully run some Python code")
print("Congratulations!")
# Out:
# You've successfully run some Python code
# Congratulations!

# %% [markdown]
# #### 직접 코드 추가해보기
#
# 위 셀에 코드를 한 줄 더 추가하고 다시 실행해보세요.
#
# #### 새 코드 셀 추가하기
#
# 새 코드 셀을 추가하려면:
# 1. 기존 코드 셀 클릭
# 2. Esc 키 누르기
# 3. a 또는 b 키 누르기
#     * a : 현재 셀 위에 추가
#     * b : 현재 셀 아래에 추가
#
# 이제 Notebook 사용법을 익혔습니다!

# %% [markdown]
# #### 실습 준비
#
# 아래 코드를 실행하세요.
#
# > Kaggle Notebook 환경에서 실행되도록 만들어진 코드라서 로컬에서는 굳이 설치 안할거고, Kaggle Notebook에서 채점 된 코드들만 깃헙에 업로드 해 놓을 예정

# %%
from learntools.core import binder; binder.bind(globals())
from learntools.python.ex1 import *

print("Setup complete! You're ready to start question 0.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from learntools.core import binder; binder.bind(globals())
#       2 from learntools.python.ex1 import *
#       3
#       4 print("Setup complete! You're ready to start question 0.")
#
# ModuleNotFoundError: No module named 'learntools.core'

# %% [markdown]
# ### 0번 문제
#
# 조금 웃긴(?) 문제입니다.
# 실습 형식에 익숙해지기 위한 문제예요.
#
# #### 질문
# > 가장 좋아하는 색깔은 무엇인가요?
#
# 아래 셀에서 color 라는 변수를 만들고 값을 넣으세요.

# %%
# color라는 변수를 만드세요
# 문자열은 작은따옴표(' ') 또는 큰따옴표(" ")로 감싸야 합니다.

color = 'lavender'

# 정답 확인, 로컬에서는 비활성화
# q0.check()

# %% [markdown]
# #### 힌트 / 정답 보기
#
# #q0.hint()
# #q0.solution()
#
# 앞의 # 을 지우면 실행됩니다.
#
# 설명
#
# '#' 은 주석(comment)입니다.
# 주석은 Python이 실행하지 않습니다.
#
# '#' 을 지우는 것을 uncomment(주석 해제) 라고 합니다.
#
#
# 다음 문제들도 같은 방식으로 진행됩니다.
#
# * 1번 문제 → q1.check()
# * 2번 문제 → q2.check()
# 처럼 번호만 바뀝니다.

# %% [markdown]
# ### 1번 문제
#
# 아래 코드를 완성하세요.
#
# | 연산자    | 이름  | 설명     |
# | ------ | --- | ------ |
# | a + b  | 덧셈  | a+b    |
# | a - b  | 뺄셈  | a-b    |
# | a * b  | 곱셈  | a×b    |
# | a / b  | 나눗셈 | a÷b    |
# | a // b | 몫   | 소수점 버림 |
# | a % b  | 나머지 | 나머지    |
# | a ** b | 제곱  | 거듭제곱   |
# | -a     | 음수화 | 부호 반전  |

# %%
pi = 3.14159 # approximate
diameter = 3

# radius 변수를 지름의 절반으로 만드세요
radius = diameter * 0.5

# 원의 넓이 공식 사용
# area = pi × radius²
area = pi * (radius**2)

# 정답 확인
# q1.check()

# %%
# Uncomment and run the lines below if you need help.
#q1.hint()
#q1.solution()

# %% [markdown]
# ### 2번 문제
#
# 변수 a 와 b 를 서로 바꾸세요(swap).
#
# a = [1, 2, 3]
# b = [3, 2, 1]
#
# #### 목표
# * a 는 원래 b 값
# * b 는 원래 a 값

# %%
a = [1, 2, 3]
b = [3, 2, 1]

temp = a
a = b
b = temp

# %%
#q2.hint()
#q2.solution()

# %% [markdown]
# ### 3a 문제
#
# 괄호를 추가해서 결과가 1 이 되게 하세요.
#
# 5 - 3 // 2

# %%
(5 - 3) // 2
# Out:
# 1

# %% [markdown]
# ### 3b 문제 🌶️
#
# 좀 더 어려운 문제입니다.
#
# 괄호를 추가해서 결과가 0 이 되게 하세요.
#
# 8 - 3 * 2 - 1 + 1

# %%
(8 - 3) * (2 - (1 + 1))
# Out:
# 0

# %% [markdown]
# ### 4번 문제
#
# Alice, Bob, Carol 이 사탕을 모아서 똑같이 나누기로 했습니다.
#
# 남는 사탕은 부숴버립니다.
#
# 예:
# * 총 91개
# * 3명이 나누면 30개씩
# * 1개 남음 → 부숨
#
# ### 문제
# 남는 사탕 개수를 계산하는 식을 작성하세요.

# %%
alice_candies = 121
bob_candies = 77
carol_candies = 109

to_smash = -1

to_smash = (alice_candies + bob_candies + carol_candies) % 3

# q4.check()
