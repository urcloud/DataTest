# %% [markdown]
# #### 시나리오 (Scenario)
#
# 당신은 최근 Los Angeles 시의 박물관 관리자로 채용되었습니다.
#
# 첫 번째 프로젝트는 아래 4개의 박물관을 분석하는 것입니다.
#
# ![image-2.png](attachment:image-2.png)
#
# 이 프로젝트에서는 LA Data Portal의 데이터를 사용하며, 각 박물관의 월별 방문자 수(monthly visitors)를 분석하게 됩니다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Step 1: 데이터 불러오기 (Load the data)
#
# 박물관 데이터를 museum_data 변수에 저장하세요.
#
# 조건
# * 파일 경로는 이미 museum_filepath에 저장되어 있음
# * 행 인덱스로 사용할 컬럼 이름은 "Date"

# %%
# Path of the file to read
museum_filepath = "../input/museum_visitors.csv"

# Fill in the line below to read the file into a variable museum_data
museum_data = pd.read_csv(museum_filepath, index_col="Date", parse_dates=True)

# Run the line below with no changes to check that you've loaded the data correctly
# step_1.check()

# %% [markdown]
# #### Step 2: 데이터 확인하기 (Review the data)
#
# #### 문제 1 - 2018년 7월 Chinese American Museum 방문자 수는?
# #### 문제 2 - 2018년 10월 Avila Adobe 방문자가 Firehouse Museum보다 몇 명 더 많았는가?

# %%
# Fill in the line below: How many visitors did the Chinese American Museum 
# receive in July 2018?
ca_museum_jul18 = 2620

# Fill in the line below: In October 2018, how many more visitors did Avila 
# Adobe receive than the Firehouse Museum?
avila_oct18 = 14658

# Check your answers
# step_2.check()

# %% [markdown]
# #### Step 3: 박물관 이사회 설득하기
#
# Firehouse Museum 은:
# "2014년에 엄청난 방문자 이벤트를 열었고,
# 비슷한 이벤트를 위해 더 많은 예산을 받아야 한다!"
# 라고 주장합니다.
#
# 반면 다른 박물관들은:
# "최근 평균 방문자 수 기준으로 예산을 나눠야 한다"
# 고 주장합니다.
#
# 시간에 따라 각 박물관 방문자 수가 어떻게 변했는지 보여주는 라인 차트를 만드세요.
#
# 조건:
# * 4개의 선(line)
# * 박물관별 방문자 수 표시

# %%
# Line chart showing the number of visitors to each museum over time
sns.lineplot(data=museum_data) # Your code here

# Check your answer
# step_3.check()

# %% [markdown]
# #### Step 4: 계절성 분석하기 (Assess seasonality)
#
# Avila Adobe 직원들은 다음 문제를 겪고 있습니다.
# * 비수기 → 직원 수 충분
# * 성수기 → 직원 부족
# 그래서 방문자 수의 계절 패턴을 예측해서 계절 직원을 미리 고용하려고 합니다.
#
# #### Part A
# Avila Adobe 방문자 수 변화만 보여주는 라인 차트 생성

# %%
# Line plot showing the number of visitors to Avila Adobe over time
sns.lineplot(data=museum_data, label="Avila Adobe") # Your code here

# Check your answer
# step_4.a.check()

# %% [markdown]
# #### Part B
#
# Avila Adobe는 어느 시기에 방문자가 더 많은가?
#
# 1. 9월~2월 (가을/겨울)
# 2. 3월~8월 (봄/여름)
# 그리고 언제 계절 직원을 더 고용해야 하는가?

# %%
# 2번
# 2번
# Check your answer (Run this code cell to receive credit!)
# step_4.b.solution()
