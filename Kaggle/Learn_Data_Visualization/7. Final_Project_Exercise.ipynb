# %% [markdown]
# #### Step 1: 노트북에 데이터셋 연결하기
#
# 먼저 Kaggle Datasets에서 CSV 데이터셋 하나를 선택하세요.
# 방법이 기억나지 않는다면 이전 튜토리얼을 다시 참고하세요.
#
# 데이터셋을 선택한 뒤:
# 1. 노트북 오른쪽 상단의 [+ Add data] 버튼 클릭
# 2. 팝업 창에서 원하는 데이터셋 검색
#
# ![image.png](attachment:image.png)
#
# 데이터셋을 찾았다면:
# * [Add] 버튼을 눌러 노트북에 연결합니다.
#
# 성공 여부 확인 방법:
# * 노트북 오른쪽의 Data 메뉴 확인
# * input 폴더 아래에 데이터셋 이름의 하위 폴더가 생기면 성공입니다.
#
# ![image-2.png](attachment:image-2.png)
#
# 데이터셋 이름 왼쪽의 화살표(carat)를 클릭하면
# CSV 파일이 포함되어 있는지도 확인할 수 있습니다.
#
# 예시:
# * dc-wikia-data.csv
# * marvel-wikia-data.csv
#
# ![image-3.png](attachment:image-3.png)
#
# CSV 파일이 포함된 데이터셋을 업로드한 후,
# 아래 코드를 수정 없이 실행하세요.

# %%
# Check for a dataset with a CSV file
# step_1.check()

# %% [markdown]
# #### Step 2: 파일 경로(filepath) 지정하기
#
# 이제 데이터셋이 연결되었으므로 CSV 파일의 경로(filepath)를 찾을 수 있습니다.
#
# 방법:
# 1. 사용할 CSV 파일 클릭
# 2. 노트북 아래쪽에 CSV 미리보기 탭 열림
# 3. 탭 상단에서 filepath 확인 가능
#
# 예시:
# ```python
# my_filepath = "../input/fivethirtyeight-comic-characters-dataset/dc-wikia-data.csv"
# ```
#
# 주의:
# * 파일 경로는 반드시 따옴표("") 안에 넣어야 합니다.
# * 그렇지 않으면 에러가 발생합니다.
#
# 파일 경로를 입력한 뒤 아래 코드를 실행하세요.

# %%
# Fill in the line below: Specify the path of the CSV file to read
my_filepath = "../input/fivethirtyeight-comic-characters-dataset/dc-wikia-data.csv"

# Check for a valid filepath to a CSV file in a dataset
# step_2.check()

# %% [markdown]
# #### Step 3: 데이터 불러오기
#
# 이제 데이터를 my_data 변수로 불러옵니다.
# 앞 단계에서 지정한 filepath를 사용하세요.

# %%
# Fill in the line below: Read the file into a variable my_data
my_data = pd.read_csv(my_filepath)

# Check that a dataset has been uploaded into my_data
# step_3.check()

# Print the first five rows of the data
my_data.head()

# %% [markdown]
# #### Step 4: 데이터 시각화하기
#
# 이제 데이터셋의 이야기를 보여주는 그래프를 직접 만들어보세요.
#
# 사용 가능한 예시:
# * 선 그래프(line chart)
# * 막대 그래프(bar chart)
# * 히트맵(heatmap)
# * 산점도(scatter plot)
# 등 자유롭게 선택 가능!

# %%
# Create a plot
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.countplot(x=my_data["bResult"])

plt.title("Blue Team Win Distribution")
plt.xlabel("Win (1) or Lose (0)")

# Check that a figure appears below
# step_4.check()
