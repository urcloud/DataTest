# %% [markdown]
# 코스를 끝까지 완료하신 것을 축하합니다!
#
# 이번 마지막 튜토리얼에서는 Kaggle 웹사이트에서 멋진 데이터 시각화를 계속 만들어갈 수 있는 효율적인 작업 흐름(workflow)을 배우게 됩니다.
#
# #### 작업 흐름 (Workflow)
#
# 먼저 Kaggle Notebooks 페이지로 이동하세요.
#
# [Kaggle Notebooks](https://www.kaggle.com/code)
#
# 그 다음:
# * 왼쪽 상단의 [+ New Notebook] 버튼을 클릭합니다.
# 이렇게 하면 새로운 노트북이 열립니다.
#
# #### 언어 확인하기
#
# 첫 번째 단계로 노트북 언어를 확인합니다.
#
# 메뉴에서:
# * File > Language
# 를 선택하세요.
#
# 만약 Python이 아니라면,
# 지금 Python으로 변경하세요.

# %% [markdown]
# #### 기본 코드 삭제 후 환경 설정 코드 입력
#
# 새 노트북에는 기본 코드가 들어있을 수 있습니다.
#
# 그 코드를 모두 삭제하고,
# 아래 코드를 입력하세요.
#
# (이 코드는 지금까지 모든 실습에서 사용했던 Python 환경 설정 코드입니다.)
#
# ```python
# import pandas as pd
# pd.plotting.register_matplotlib_converters()
# import matplotlib.pyplot as plt
# %matplotlib inline
# import seaborn as sns
# print("Setup Complete")
# ```
#
# 실행 결과:
# ```python
# Setup Complete
# ```

# %% [markdown]
# #### 다음 단계: 데이터셋 연결하기
#
# 이제 데이터 시각화를 하기 전에 데이터셋을 노트북에 연결해야 합니다.
# (이 방법은 이전 튜토리얼에서 배웠습니다.)
#
# #### 마지막 단계: 그래프 저장하기
#
# 그래프를 생성한 뒤에는:
# * 이미지 파일로 저장해서
# * 발표 자료(PPT) 등에 쉽게 추가할 수 있습니다.
#
# 예시:
# ```python
# plt.savefig("my_chart.png")
# ```
# 이렇게 하면 현재 작업 폴더에 my_chart.png 파일이 저장됩니다.
#
# 즉, 전체 흐름은 다음과 같습니다.
# 1. 새 Notebook 생성
# 2. Python 환경 설정
# 3. 데이터셋 연결
# 4. 데이터 분석 및 시각화
# 5. 그래프 이미지 저장
# 6. 발표 자료나 포트폴리오에 활용
# 입니다.
