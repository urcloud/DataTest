# %% [markdown]
# #### Step 1: 피드백 시스템 살펴보기
#
# 각 실습 문제에서는 실제 데이터를 활용해 새로운 기술을 연습합니다.
# 그리고 작업 도중에 다음과 같은 피드백을 받을 수 있습니다.
# * 정답 여부 확인
# * 맞춤형 힌트
# * 공식 정답 확인
#
# 먼저 간단한 예제로 피드백 시스템을 체험해봅시다.
# 다음 순서대로 진행하세요.
#
# #### 1단계
#
# 아래 코드 셀을 수정하지 말고 실행하세요.
# ```python
# # Fill in the line below
# one = ____
#
# # Check your answer
# step_1.check()
# ```
#
# 다음과 같은 메시지가 출력됩니다.
# > Check: When you've updated the starter code, check() will tell you whether your code is correct. You need to update the code that creates variable one
#
# 의미:
# * one 변수에 값을 넣어야 한다는 뜻입니다.
# * 현재 ____ 부분이 비어 있어서 오류가 발생합니다.
#
# #### 2단계
#
# ____ 를 2로 바꾸세요.
#
# ```python
# one = 2
# ```
#
# 실행하면 다음과 같은 결과가 나옵니다.
# > Incorrect: Incorrect value for one: 2
# 즉, 아직 정답이 아닙니다.
#
# #### 3단계
#
# 이번에는 2를 1로 바꾸세요.
#
# ```python
# one = 1
# ```
# 실행하면 정답(Correct)으로 표시됩니다!
#
# 🎉 첫 번째 문제를 완료했습니다.
# 이 문제에서는 여러분이 직접 변수 one의 값을 채워야 했습니다.
#
# 주의할 점:
# ```python
# step_1.check()
# ```
# 같은 정답 확인 코드는 수정하면 안 됩니다.
# 그대로 실행해야 합니다.
#
# #### 힌트와 정답 보기
#
# 문제가 어려울 경우:
# * 힌트(hint)
# * 공식 정답(solution)
# 을 볼 수 있습니다.
#
# 아래 코드를 실행해보세요.
# ```python
# step_1.hint()
# step_1.solution()
# ```

# %% [markdown]
# #### Step 2: 데이터 불러오기
#
# 이제 데이터 시각화를 시작할 준비가 되었습니다!
# 이전 튜토리얼에서 사용했던 FIFA 데이터를 불러옵니다.
# 아래 코드는 이미 작성되어 있으므로 그냥 실행만 하면 됩니다.
#
# ```python
# # Path of the file to read
# fifa_filepath = "../input/fifa.csv"
#
# # Read the file into a variable fifa_data
# fifa_data = pd.read_csv(fifa_filepath, index_col="Date", parse_dates=True)
#
# # Check your answer
# step_2.check()
# ```
# Correct가 나오면 성공입니다.
#
# #### 주석(Comment)과 실행 코드
#
# 다시 한번 차이를 정리하면:
# #### 주석(Comment)
#
# `#` 이것은 주석입니다
# * #로 시작
# * 컴퓨터가 무시함
# * 설명용 텍스트
#
# #### 실행 코드(Executable code)
#
# 컴퓨터가 실제로 실행하는 코드입니다.
# 아래 셀은 모든 줄이 주석입니다.
#
# ```python
# # Uncomment the line below to receive a hint
# #step_2.hint()
# #step_2.solution()
# ```
# 이 상태로 실행하면 아무 출력도 나오지 않습니다.
#
# #### Uncomment(주석 해제)
#
# 다음처럼 `#`를 제거해보세요.
#
# ```python
# # Uncomment the line below to receive a hint
# step_2.hint()
# #step_2.solution()
# ```
#
# 이렇게 하면:
# * 주석 → 실행 코드
# 로 바뀝니다.
#
# 이것을 Uncomment(주석 해제) 라고 합니다.
# 실행하면 Hint가 출력됩니다.
#
# 이번에는 solution도 주석 해제해보세요.
#
# ```python
# # Uncomment the line below to receive a hint
# step_2.hint()
# step_2.solution()
# ```
#
# 실행하면:
# * Hint
# * Solution
# 둘 다 출력됩니다.
#
# 문제를 풀다가 막히면:
# * 정답을 맞추기 전에
# * 힌트나 정답을 먼저 봐도 괜찮습니다!

# %% [markdown]
# #### Step 3: 데이터 시각화하기
#
# 이제 데이터를 그래프로 그려볼 차례입니다!
# 아래 코드를 수정 없이 실행하세요.
#
# ```python
# # Set the width and height of the figure
# plt.figure(figsize=(16,6))
#
# # Line chart showing how FIFA rankings evolved over time
# sns.lineplot(data=fifa_data)
#
# # Check your answer
# step_3.a.check()
# ```
# 아직 코드 의미를 완전히 이해하지 못해도 괜찮습니다 🙂
# 다음 튜토리얼에서 자세히 배우게 됩니다.
#
# #### 그래프 해석 문제
#
# 모든 문제에서 코드를 작성하는 것은 아닙니다.
# 그래프를 보고 해석하는 문제도 있습니다.
#
# 예시 질문:
# 데이터에 포함된 기간 동안, 최소 5년 연속으로 FIFA 랭킹 1위를 유지한 국가는 어디인가?
#
# 힌트를 보려면 아래 코드의 주석을 해제하세요.
# ```python
# #step_3.b.hint()
# ```
# ↓
# ```python
# step_3.b.hint()
# ```
#
# 답을 생각한 뒤에는 아래 코드를 실행해 정답을 확인합니다.
# ```python
# # Check your answer (Run this code cell to receive credit!)
# step_3.b.solution()
# ```
