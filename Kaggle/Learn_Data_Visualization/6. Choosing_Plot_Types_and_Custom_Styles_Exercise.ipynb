# %% [markdown]
# #### seaborn 스타일 적용해보기
#
# 아래 명령어를 실행해서 "dark" 테마를 적용해보세요.
#
# ```python
# # 그래프 스타일 변경
# sns.set_style("dark")
#
# # 선 그래프
# plt.figure(figsize=(12,6))
# sns.lineplot(data=spotify_data)
#
# # 코드 셀 실행 후 문제 완료 처리
# # step_1.check()
# ```
#
# 아래와 같은 경고 메시지가 출력될 수 있습니다.
#
# ```python
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119:
# FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version.
# Convert inf values to NaN before operating instead.
# ```
#
# 이 경고는:
# 현재 seaborn 내부에서 사용 중인 옵션이 미래 버전에서 제거될 예정이라는 뜻입니다.
# 학습 진행에는 문제 없으며 무시해도 됩니다.
